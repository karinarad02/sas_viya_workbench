# %% [markdown]
# # Acessing and readin Data Lake files
# Begin by importing pandas. Ensure you have GCSFS and pyarrow installed on your workbench for this process to work!

# %%
import pandas as pd

# %% [markdown]
# Initialize the gcs key variable with the JSON file location.

# %%
gcs_key = '../keys/gcl-sas1-reader.json'

# %% [markdown]
# Define the path to the gcs

# %%
bucket_name = 'sas1-learn'
parquet_filename = 'customer_churn_data.parquet'

file_path = 'gcs://' + bucket_name + '/data' + parquet_filename
print(file_path)
# Out:
# gcs://sas1-learn/datacustomer_churn_data.parquet

# %% [markdown]
# Read the Parquet file from the path to the gcs

# %%
# cust_churn_df = pd.read_parquet(file_path, storage_options={"token":gcs_key})

# Improv
cust_churn_df = pd.read_parquet("/workspaces/myfolder/sas_viya_workbench/sas1/data/input/gcs")
cust_churn_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 30 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   LostCustomer            10000 non-null  float64
#  1   regionPctCustomers      10000 non-null  float64
#  2   numOfTotalReturns       10000 non-null  float64
#  3   wksSinceLastPurch       10000 non-null  float64
#  4   basktPurchCount12Month  10000 non-null  float64
#  5   LastPurchaseAmount      10000 non-null  float64
#  6   AvgPurchaseAmount12     10000 non-null  float64
#  7   AvgPurchaseAmountTotal  10000 non-null  float64
#  8   intAdExposureCount12    10000 non-null  float64
#  9   intAdExposureCount36    10000 non-null  float64
#  10  intAdExposureCountAll   10000 non-null  float64
#  11  socialMediaAdCount12    10000 non-null  float64
#  12  socialMediaAdCount36    10000 non-null  float64
#  13  socialMediaAdCountAll   10000 non-null  float64
#  14  totalNumProdPurchased   10000 non-null  float64
#  15  custInitiatedContacts   10000 non-null  float64
#  16  avgDiscountValue12      7236 non-null   float64
#  17  customersales           10000 non-null  float64
#  18  wksSinceFirstPurch      10000 non-null  float64
#  19  DemHomeOwner            5000 non-null   object
#  20  customerGender          5000 non-null   object
#  21  EstimatedIncome         5000 non-null   float64
#  22  regionMedHomeVal        5000 non-null   float64
#  23  birthDate               3741 non-null   float64
#  24  customerSubscrStat      5000 non-null   object
#  25  techSupportEval         4730 non-null   float64
#  26  Review_Text             5000 non-null   object
#  27  Title                   5000 non-null   object
#  28  customerAge             3741 non-null   float64
#  29  AvgPurchasePerAd12      5000 non-null   float64
# dtypes: float64(25), object(5)
# memory usage: 2.3+ MB

# %%
cust_churn_df.head()
# Out:
#    LostCustomer  regionPctCustomers  numOfTotalReturns  wksSinceLastPurch  \
# 0           0.0                66.0                0.0               19.0
# 1           0.0                22.0                1.0               17.0
# 2           0.0                24.0                2.0               18.0
# 3           0.0                27.0                0.0               18.0
# 4           0.0                42.0                2.0               22.0
#
#    basktPurchCount12Month  LastPurchaseAmount  AvgPurchaseAmount12  \
# 0                     5.0                75.0                75.00
# 1                     5.0                75.0                75.00
# 2                     3.0               105.0               118.35
# 3                     5.0                80.0                80.00
# 4                     3.0                80.0                52.50
#
#    AvgPurchaseAmountTotal  intAdExposureCount12  intAdExposureCount36  ...  \
# 0                   80.65                  13.0                  33.0  ...
# 1                   75.00                  10.0                  15.0  ...
# 2                  106.00                  14.0                  30.0  ...
# 3                   61.80                  13.0                  32.0  ...
# 4                   51.00                  12.0                  32.0  ...
#
#    customerGender  EstimatedIncome  regionMedHomeVal     birthDate  \
# 0            b'F'          66000.0           73450.0  16001.326392
# 1            b'F'          70000.0           82810.0  13725.834941
# 2            b'F'          51000.0           59930.0  13082.193529
# 3            b'M'          84000.0           42250.0  14720.640273
# 4            b'F'         100000.0          158730.0  12506.142352
#
#    customerSubscrStat  techSupportEval  Review_Text  \
# 0         b'Platinum'              3.0          b''
# 1         b'Gold    '              5.0          b''
# 2         b'Platinum'              5.0          b''
# 3         b'Platinum'              5.0          b''
# 4         b'Platinum'              5.0          b''
#
#                                                Title  customerAge  \
# 0  b'                                            ...         21.0
# 1  b'                                            ...         27.0
# 2  b'                                            ...         29.0
# 3  b'                                            ...         24.0
# 4  b'                                            ...         30.0
#
#   AvgPurchasePerAd12
# 0           5.769231
# 1           7.500000
# 2           8.453571
# 3           6.153846
# 4           4.375000
#
# [5 rows x 30 columns]
